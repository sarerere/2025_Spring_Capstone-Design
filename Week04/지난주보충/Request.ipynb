# %%
! pip install fastapi --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.9/94.9 kB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 5.3 MB/s eta 0:00:00

# %% [markdown]
# ### Request는 FastAPI에서 HTTP 요청을 처리하기 위해 사용하는 객체
# ### starlette.requests.Request 클래스를 기반으로 하며, HTTP 요청과 관련된 다양한 정보를 제공

# %%
from fastapi import Request

# %%
request= Request
request
# Out:
# starlette.requests.Request

# %%
print(f"method: {request.method}. client: {request.client}")
# Out:
# method: <property object at 0x7b3bda040f40>. client: <property object at 0x7b3bda040cc0>

# %%
from fastapi import FastAPI, Request  # FastAPI 및 Request 객체 임포트
from starlette.testclient import TestClient  # TestClient를 사용하여 요청 테스트

# FastAPI 애플리케이션 객체 생성
app = FastAPI()

# Request 객체를 활용하여 HTTP 요청 정보를 반환하는 엔드포인트
@app.get("/")  # GET 요청이 들어올 경우 실행
async def get_request_info(request: Request):
    return {
        "method": request.method,        # HTTP 요청 방식 (예: GET, POST, PUT 등)
        "client": request.client,        # 요청을 보낸 클라이언트 (IP 및 포트 정보 포함)
        "full_url": str(request.url),    # 요청한 전체 URL
        "base_url": str(request.base_url),  # 기본 URL (도메인 및 포트만 포함)
        "path_params": request.path_params,  # 경로 매개변수 (없으면 빈 딕셔너리)
        "query_params": request.query_params,  # 쿼리 스트링 파라미터 (예: `?name=John&age=30`)
        "cookies": request.cookies       # 요청에 포함된 쿠키 값
    }

# %%
# TestClient를 사용하여 API 요청을 테스트 (FastAPI 서버 실행 없이 요청 가능)
client = TestClient(app)  # FastAPI 애플리케이션을 위한 테스트 클라이언트 생성
response = client.get("/")  # 임의의 GET 요청을 실행
print(response.json())  # 응답 데이터를 JSON 형식으로 출력
# Out:
# {'method': 'GET', 'client': ['testclient', 50000], 'full_url': 'http://testserver/', 'base_url': 'http://testserver/', 'path_params': {}, 'query_params': {}, 'cookies': {}}

# %%
import requests

r = requests.get('https://www.google.com')  # Add 'https://' to the URL
r.status_code
# Out:
# 200

# %%
r.headers['content-type']
# Out:
# 'text/html; charset=ISO-8859-1'

# %%
r.encoding
# Out:
# 'ISO-8859-1'

# %%
r.text
# Out:
# '<!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="en"><head><meta content="Search the world\'s information, including webpages, images, videos and more. Google has many special features to help you find exactly what you\'re looking for." name="description"><meta content="noodp, " name="robots"><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/logos/doodles/2025/st-patricks-day-2025-6753651837110639.3-l.png" itemprop="image"><meta content="St. Patrick\'s Day 2025" property="twitter:title"><meta content="St. Patrick\'s Day 2025! #GoogleDoodle" property="twitter:description"><meta content="St. Patrick\'s Day 2025! #GoogleDoodle" property="og:description"><meta content="summary_large_image" property="twitter:card"><meta content="@GoogleDoodles" property="twitter:site"><meta content="https://www.google.com/logos/doodles/2025/st-patricks-day-2025-6753651837110639.2-2x.png" property="twitter:image"><meta content="https://www.google.com/logos/doodles/2025/st-patricks-day-2025-6753651837110639.2-2x.png" property="og:image"><meta content="1000" property="og:image:width"><meta content="400" property="og:image:height"><title>Google</title><script nonce="6U5vs414flCsfmERlLNSXQ">(function(){var _g={kEI:\'2u3YZ5bXB4LDkPIP5ZqWsAg\',kEXPI:\'0,202791,3497476,682,435,541533,2891,89155,78219,266577,247319,13732,1,28992,5230280,11449,25,35,8834858,79,2,1,7,2,2,8,27977576,25228681,123988,14280,8181,5934,62507,2663,3431,3319,23878,9140,4599,328,6225,1116,9302,23893,29144,710,1341,13708,8210,893,1,2,2390,2353,1781,12133,9173,33,9041,696,152,3,16816,10666,9763,1,11580,8341,41,5987,7652,1,4914,1827,4106,352,12340,6540,1877,3993,950,2150,756,3851,7,5773,4310,9174,3168,9171,1789,4719,837,6381,226,2727,677,957,3261,459,2531,28,7,1,1293,972,6,3651,190,170,1,654,239,56,1023,1,831,80,141,1,2944,1362,5,1602,1681,569,1791,576,151,1671,427,2,868,3856,1641,201,354,658,609,3143,808,459,6,99,110,5633,1762,663,2818,1475,2430,858,683,726,2,2,638,813,108,817,238,1210,4,280,7,1,1156,1319,140,976,66,10,617,11,1,296,1,12,1011,607,1337,340,181,83,755,241,105,2,6,302,223,1,481,16,85,67,443,438,237,334,123,540,3,2,159,2,185,455,5,1149,254,1395,5,345,8,573,91,449,537,1100,620,502,76,739,182,22,76,1535,2,171,13,400,148,136,108,369,218,74,196,165,209,57,298,9,2,636,671,259,180,97,558,310,154,151,472,148,3,22,293,164,220,4,193,2,1,6,530,287,161,281,2,1,2,2,2,39,505,4,124,114,31,543,72,110,846,176,2,817,351,312,150,192,2,2,371,36,22,2,95,462,720,131,3,399,501,505,254,1171,2,64,561,1738,2,21328659,18,2017,1207,510,609,197,8,5638,135,198,844,5,1725,3102,2216,162,306,3765265,2244575,1144792\',kBL:\'CNsO\',kOPI:89978449};(function(){var a;((a=window.google)==null?0:a.stvsc)?google.kEI=_g.kEI:window.google=_g;}).call(this);})();(function(){google.sn=\'webhp\';google.kHL=\'en\';})();(function(){\nvar g=this||self;function k(){return window.google&&window.google.kOPI||null};var l,m=[];function n(a){for(var b;a&&(!a.getAttribute||!(b=a.getAttribute("eid")));)a=a.parentNode;return b||l}function p(a){for(var b=null;a&&(!a.getAttribute||!(b=a.getAttribute("leid")));)a=a.parentNode;return b}function q(a){/^http:/i.test(a)&&window.location.protocol==="https:"&&(google.ml&&google.ml(Error("a"),!1,{src:a,glmm:1}),a="");return a}\nfunction r(a,b,d,c,h){var e="";b.search("&ei=")===-1&&(e="&ei="+n(c),b.search("&lei=")===-1&&(c=p(c))&&(e+="&lei="+c));var f=b.search("&cshid=")===-1&&a!=="slh";c="&zx="+Date.now().toString();g._cshid&&f&&(c+="&cshid="+g._cshid);(d=d())&&(c+="&opi="+d);return"/"+(h||"gen_204")+"?atyp=i&ct="+String(a)+"&cad="+(b+e+c)};l=google.kEI;google.getEI=n;google.getLEI=p;google.ml=function(){return null};google.log=function(a,b,d,c,h,e){e=e===void 0?k:e;d||(d=r(a,b,e,c,h));if(d=q(d)){a=new Image;var f=m.length;m[f]=a;a.onerror=a.onload=a.onabort=function(){delete m[f]};a.src=d}};google.logUrl=function(a,b){b=b===void 0?k:b;return r("",a,b)};}).call(this);(function(){google.y={};google.sy=[];var d;(d=google).x||(d.x=fu ...

# %%
r = requests.get('https://api.github.com/events')
print(r.status_code)
print(r.headers['content-type'])
print(r.encoding)
print(r.text)
# Out:
# 200
# application/json; charset=utf-8
# utf-8
# [{"id":"47666276087","type":"CreateEvent","actor":{"id":172470827,"login":"estersky","display_login":"estersky","gravatar_id":"","url":"https://api.github.com/users/estersky","avatar_url":"https://avatars.githubusercontent.com/u/172470827?"},"repo":{"id":950368210,"name":"estersky/Toko-Kue","url":"https://api.github.com/repos/estersky/Toko-Kue"},"payload":{"ref":null,"ref_type":"repository","master_branch":"main","description":null,"pusher_type":"user"},"public":true,"created_at":"2025-03-18T03:49:47Z"},{"id":"47666276067","type":"PushEvent","actor":{"id":104544900,"login":"aws-aemilia-bah","display_login":"aws-aemilia-bah","gravatar_id":"","url":"https://api.github.com/users/aws-aemilia-bah","avatar_url":"https://avatars.githubusercontent.com/u/104544900?"},"repo":{"id":812030385,"name":"aws-aemilia-bah/Github-PR-Commit-Integration-Test-DoNotTouch-GitHubAutoBuildPushCanaryTest-v1-prod-me-south-1","url":"https://api.github.com/repos/aws-aemilia-bah/Github-PR-Commit-Integration-Test-DoNotTouch-GitHubAutoBuildPushCanaryTest-v1-prod-me-south-1"},"payload":{"repository_id":812030385,"push_id":23228143576,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"197d3670fd81a392310d3cc0632f3c80710809e8","before":"6d53790a3680e0b6d7d2c90e5e73d31d00f01716","commits":[{"sha":"197d3670fd81a392310d3cc0632f3c80710809e8","author":{"email":"104544900+aws-aemilia-bah@users.noreply.github.com","name":"aws-aemilia-bah"},"message":"commit from integ tests","distinct":true,"url":"https://api.github.com/repos/aws-aemilia-bah/Github-PR-Commit-Integration-Test-DoNotTouch-GitHubAutoBuildPushCanaryTest-v1-prod-me-south-1/commits/197d3670fd81a392310d3cc0632f3c80710809e8"}]},"public":true,"created_at":"2025-03-18T03:49:47Z"},{"id":"47666276062","type":"CreateEvent","actor":{"id":20842956,"login":"ddrandy","display_login":"ddrandy","gravatar_id":"","url":"https://api.github.com/users/ddrandy","avatar_url":"https://avatars.githubusercontent.com/u/20842956?"},"repo":{"id":950365901,"name":"S125PRT840T25/llm-bert","url":"https://api.github.com/repos/S125PRT840T25/llm-bert"},"payload":{"ref":"master","ref_type":"branch","master_branch":"main","description":null,"pusher_type":"user"},"public":true,"created_at":"2025-03-18T03:49:47Z","org":{"id":203746730,"login":"S125PRT840T25","gravatar_id":"","url":"https://api.github.com/orgs/S125PRT840T25","avatar_url":"https://avatars.githubusercontent.com/u/203746730?"}},{"id":"47666276026","type":"PushEvent","actor":{"id":41898282,"login":"github-actions[bot]","display_login":"github-actions","gravatar_id":"","url":"https://api.github.com/users/github-actions[bot]","avatar_url":"https://avatars.githubusercontent.com/u/41898282?"},"repo":{"id":867623432,"name":"xrwt/degisiklik-yapan-sistem","url":"https://api.github.com/repos/xrwt/degisiklik-yapan-sistem"},"payload":{"repository_id":867623432,"push_id":23228143573,"size":2,"distinct_size":2,"ref":"refs/heads/main","head":"1da79d57f1d80988159696b9e0e095f5587fbe7b","before":"5088dadf5eada2207f398957b75ca9f6134083bd","commits":[{"sha":"d4fc77aa4fa63db821e5607f598608b55a486ac3","author":{"email":"xrqu.live@gmail.com","name":"xrwt"},"message":"[➕] Güncelleme (1. Ekleme, 932. Değişiklik)","distinct":true,"url":"https://api.github.com/repos/xrwt/degisiklik-yapan-sistem/commits/d4fc77aa4fa63db821e5607f598608b55a486ac3"},{"sha":"1da79d57f1d80988159696b9e0e095f5587fbe7b","author":{"email":"xrqu.live@gmail.com","name":"xrwt"},"message":"[➖] Güncelleme (1. Çıkarma, 932. Değişiklik)","distinct":true,"url":"https://api.github.com/repos/xrwt/degisiklik-yapan-sistem/commits/1da79d57f1d80988159696b9e0e095f5587fbe7b"}]},"public":true,"created_at":"2025-03-18T03:49:47Z"},{"id":"47666276059","type":"PushEvent","actor":{"id":199686514,"login":"yiting0318","display_login":"yiting0318","gravatar_id":"","url":"https://api.github.com/users/yiting0318","avatar_url":"https://avatars.githubusercontent.com/u/199686514?"},"repo":{"id":934515311,"name":"yiting0318/yiting0318.github.io","url":"http ...

# %%
r = requests.post('https://httpbin.org/post', data={'key': 'value'})

# %%
r = requests.put('https://httpbin.org/put', data={'key': 'value'})
print(r.status_code)
r = requests.delete('https://httpbin.org/delete')
print(r.status_code)
r = requests.head('https://httpbin.org/get')
print(r.status_code)
r = requests.options('https://httpbin.org/get')
print(r.status_code)
# Out:
# 200
# 200
# 200
# 200

# %%
payload = {'key1': 'value1', 'key2': 'value2'}
r = requests.get('https://httpbin.org/get', params=payload)
print(r.url)
# Out:
# https://httpbin.org/get?key1=value1&key2=value2

# %%
payload = {'key1': 'value1', 'key2': ['value2', 'value3']}
r = requests.get('https://httpbin.org/get', params=payload)
print(r.url)
# Out:
# https://httpbin.org/get?key1=value1&key2=value2&key2=value3

# %%
import requests
r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"47666313895","type":"PushEvent","actor":{"id":149133477,"login":"920513","display_login":"920513","gravatar_id":"","url":"https://api.github.com/users/920513","avatar_url":"https://avatars.githubusercontent.com/u/149133477?"},"repo":{"id":941763649,"name":"920513/ntdtv","url":"https://api.github.com/repos/920513/ntdtv"},"payload":{"repository_id":941763649,"push_id":23228164559,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"f62b24b5e3141bc5f4589736926038ae30d70c85","before":"1664a23c9fea746013ff447cd2f10dead8090671","commits":[{"sha":"f62b24b5e3141bc5f4589736926038ae30d70c85","author":{"email":"149133477+920513@users.noreply.github.com","name":"920513"},"message":"Update","distinct":true,"url":"https://api.github.com/repos/920513/ntdtv/commits/f62b24b5e3141bc5f4589736926038ae30d70c85"}]},"public":true,"created_at":"2025-03-18T03:51:45Z"},{"id":"47666313875","type":"PushEvent","actor":{"id":132093571,"login":"BuzzLaiclere03","display_login":"BuzzLaiclere03","gravatar_id":"","url":"https://api.github.com/users/BuzzLaiclere03","avatar_url":"https://avatars.githubusercontent.com/u/132093571?"},"repo":{"id":949059253,"name":"BuzzLaiclere03/GRO-S4-APP5","url":"https://api.github.com/repos/BuzzLaiclere03/GRO-S4-APP5"},"payload":{"repository_id":949059253,"push_id":23228164564,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"1fa2e66559e65c39435b72750756853598e542e7","before":"dfd0a295ffac883d73406c0d6c296e7bc27ecb50","commits":[{"sha":"1fa2e66559e65c39435b72750756853598e542e7","author":{"email":"samuelh1103@hotmail.com","name":"Samuel Hamelin"},"message":"midnight commit","distinct":true,"url":"https://api.github.com/repos/BuzzLaiclere03/GRO-S4-APP5/commits/1fa2e66559e65c39435b72750756853598e542e7"}]},"public":true,"created_at":"2025-03-18T03:51:45Z"},{"id":"47666313866","type":"PullRequestEvent","actor":{"id":118154470,"login":"hunterckx","display_login":"hunterckx","gravatar_id":"","url":"https://api.github.com/users/hunterckx","avatar_url":"https://avatars.githubusercontent.com/u/118154470?"},"repo":{"id":183135467,"name":"anvilproject/anvil-portal","url":"https://api.github.com/repos/anvilproject/anvil-portal"},"payload":{"action":"opened","number":3578,"pull_request":{"url":"https://api.github.com/repos/anvilproject/anvil-portal/pulls/3578","id":2399630028,"node_id":"PR_kwDOCups686PB3LM","html_url":"https://github.com/anvilproject/anvil-portal/pull/3578","diff_url":"https://github.com/anvilproject/anvil-portal/pull/3578.diff","patch_url":"https://github.com/anvilproject/anvil-portal/pull/3578.patch","issue_url":"https://api.github.com/repos/anvilproject/anvil-portal/issues/3578","number":3578,"state":"open","locked":false,"title":"chore: add pageviews to analytics report (#3574)","user":{"login":"hunterckx","id":118154470,"node_id":"U_kgDOBwrk5g","avatar_url":"https://avatars.githubusercontent.com/u/118154470?v=4","gravatar_id":"","url":"https://api.github.com/users/hunterckx","html_url":"https://github.com/hunterckx","followers_url":"https://api.github.com/users/hunterckx/followers","following_url":"https://api.github.com/users/hunterckx/following{/other_user}","gists_url":"https://api.github.com/users/hunterckx/gists{/gist_id}","starred_url":"https://api.github.com/users/hunterckx/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/hunterckx/subscriptions","organizations_url":"https://api.github.com/users/hunterckx/orgs","repos_url":"https://api.github.com/users/hunterckx/repos","events_url":"https://api.github.com/users/hunterckx/events{/privacy}","received_events_url":"https://api.github.com/users/hunterckx/received_events","type":"User","user_view_type":"public","site_admin":false},"body":"Closes #3574 (see ticket for report link)\\r\\n\\r\\nThis also includes some simplifications using the features added in the latest analytics package version","created_at":"2025-03-18T03:51:44Z","updated_at":"2025-03-18T03:51:44Z","closed_at":null,"merged_at":null,"merge_commit_sha":nu ...

# %%
# prompt: r을 json 형태로 읽기

import json
import requests

r = requests.get('https://api.github.com/events')

# r.text를 JSON 형태로 파싱
try:
  json_data = json.loads(r.text)
  print(json.dumps(json_data, indent=2))  # 들여쓰기를 사용하여 JSON을 출력
except json.JSONDecodeError as e:
  print(f"JSON 파싱 오류: {e}")
r.text
# Out:
# [
#   {
#     "id": "47666338179",
#     "type": "CreateEvent",
#     "actor": {
#       "id": 202667464,
#       "login": "DianaPutri09",
#       "display_login": "DianaPutri09",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/DianaPutri09",
#       "avatar_url": "https://avatars.githubusercontent.com/u/202667464?"
#     },
#     "repo": {
#       "id": 950369337,
#       "name": "DianaPutri09/Simple-Finding-Path---BFS",
#       "url": "https://api.github.com/repos/DianaPutri09/Simple-Finding-Path---BFS"
#     },
#     "payload": {
#       "ref": "main",
#       "ref_type": "branch",
#       "master_branch": "main",
#       "description": null,
#       "pusher_type": "user"
#     },
#     "public": true,
#     "created_at": "2025-03-18T03:53:03Z"
#   },
#   {
#     "id": "47666338106",
#     "type": "PushEvent",
#     "actor": {
#       "id": 41898282,
#       "login": "github-actions[bot]",
#       "display_login": "github-actions",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/github-actions[bot]",
#       "avatar_url": "https://avatars.githubusercontent.com/u/41898282?"
#     },
#     "repo": {
#       "id": 813600738,
#       "name": "SofyanJames/Lava-testnet",
#       "url": "https://api.github.com/repos/SofyanJames/Lava-testnet"
#     },
#     "payload": {
#       "repository_id": 813600738,
#       "push_id": 23228177674,
#       "size": 1,
#       "distinct_size": 1,
#       "ref": "refs/heads/master",
#       "head": "b5de520623a5f316daff1c4b17652db6082d1b20",
#       "before": "9018e6338fad5142c9d6e4c104e3b6979ecbb616",
#       "commits": [
#         {
#           "sha": "b5de520623a5f316daff1c4b17652db6082d1b20",
#           "author": {
#             "email": "sofyanjames71@gmail.com",
#             "name": "SofyanJames"
#           },
#           "message": "\ud83d\udd27 Refactor NEAR network",
#           "distinct": true,
#           "url": "https://api.github.com/repos/SofyanJames/Lava-testnet/commits/b5de520623a5f316daff1c4b17652db6082d1b20"
#         }
#       ]
#     },
#     "public": true,
#     "created_at": "2025-03-18T03:53:03Z"
#   },
#   {
#     "id": "47666338126",
#     "type": "PushEvent",
#     "actor": {
#       "id": 41898282,
#       "login": "github-actions[bot]",
#       "display_login": "github-actions",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/github-actions[bot]",
#       "avatar_url": "https://avatars.githubusercontent.com/u/41898282?"
#     },
#     "repo": {
#       "id": 840148192,
#       "name": "nectariferous/TestFlight",
#       "url": "https://api.github.com/repos/nectariferous/TestFlight"
#     },
#     "payload": {
#       "repository_id": 840148192,
#       "push_id": 23228177701,
#       "size": 1,
#       "distinct_size": 1,
#       "ref": "refs/heads/main",
#       "head": "f8c8eb3b525c76993df2fff944bffb6298e5e6b7",
#       "before": "3b70a232cebda487c0f87ec0b42a8210be96056b",
#       "commits": [
#         {
#           "sha": "f8c8eb3b525c76993df2fff944bffb6298e5e6b7",
#           "author": {
#             "email": "ibbles@hotmail.com",
#             "name": "Martin Nilsson"
#           },
#           "message": "Daily update at 2025-03-18 03:53:01",
#           "distinct": true,
#           "url": "https://api.github.com/repos/nectariferous/TestFlight/commits/f8c8eb3b525c76993df2fff944bffb6298e5e6b7"
#         }
#       ]
#     },
#     "public": true,
#     "created_at": "2025-03-18T03:53:03Z"
#   },
#   {
#     "id": "47666338107",
#     "type": "PushEvent",
#     "actor": {
#       "id": 41898282,
#       "login": "github-actions[bot]",
#       "display_login": "github-actions",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/github-actions[bot]",
#       "avatar_url": "https://avatars.githubusercontent.com/u/41898282?"
#     },
#     "repo": {
#       "id": 812864746,
#       "name": "taktikorg/exercitationem-modi-dicta",
#       "url": "https://api.github.com/repos/taktikorg/exercitationem-modi-dicta"
#     },
#     "payload": {
#       "repository_id": 812864746,
#       "push_id": 23228177659,
#       "size": 1,
#       "distinct_size": 1,
#       "ref": "refs/heads/main",
#       "head": "40e8fffb4b6b0b8a745de0244b84fc80ace93c07",
#       "before": "dc8092a6157537ed966376ad1f7df6c5df318413",
#       "commits": [
#         {
#           "sha": "40e8fffb4b6b0b8a745de0244b84fc80ace93c07",
#           "author": {
#             "email": "12395584+taktikangt6@users.noreply.github.com",
#             "name": "taktikangt6"
#           },
#           "message": "New updated version 8.27.247",
#           "distinct": true,
#           "url": "https://api.github.com/repos/taktikorg/exercitationem-modi-dicta/commits/40e8fffb4b6b0b8a745de0244b84fc80ace93c07"
#         }
#       ]
#     },
#     "public": true,
#     "created_at": "2025-03-18T03:53:03Z",
#     "org": {
#       "id": 167952281,
#       "login": "taktikorg",
#       "gravatar_id": "",
#       "url": "https://api.github.com/orgs/taktikorg",
#       "avatar_url": "https://avatars.githubusercontent.com/u/167952281?"
#     }
#   },
#   {
#     "id": "47666338130",
#     "type": "IssueCommentEvent",
#     "actor": {
#       "id": 23240686,
#       "login": "VaterOtter",
#       "display_login": "VaterOtter",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/VaterOtter",
#       "avatar_url": "https://avatars.githubusercontent.com/u/23240686?"
#     },
#     "repo": {
#       "id": 932465330,
#       "name": "koii-network/prometheus-beta",
#       "url": "https://api.github.com/repos/koii-network/prometheus-beta"
#     },
#     "payload": {
#       "action": "created",
#       "issue": {
#         "url": "https://api.github.com/repos/koii-network/prometheus-beta/issues/8429",
#         "repository_url": "https://api.github.com/repos/koii-network/prometheus-beta",
#         "labels_url": "https://api.github.com/repos/koii-network/prometheus-beta/issues/8429/labels{/name}",
#         "comments_url": "https://api.github.com/repos/koii-network/prometheus-beta/issues/8429/comments",
#         "events_url": "https://api.github.com/repos/koii-network/prometheus-beta/issues/8429/events",
#         "html_url": "https://github.com/koii-network/prometheus-beta/pull/8429",
#         "id": 2926895878,
#         "node_id": "PR_kwDON5RKss6PBbUh",
#         "number": 8429,
#         "title": "Implement JSON Logging Function with Proper Spacing",
#         "user": {
#           "login": "Yoyo-test-74",
#           "id": 203502243,
#           "node_id": "U_kgDODCEyow",
#           "avatar_url": "https://avatars.githubusercontent.com/u/203502243?v=4",
#           "gravatar_id": "",
#           "url": "https://api.github.com/users/Yoyo-test-74",
#           "html_url": "https://github.com/Yoyo-test-74",
#           "followers_url": "https://api.github.com/users/Yoyo-test-74/followers",
#           "following_url": "https://api.github.com/users/Yoyo-test-74/following{/other_user}",
#           "gists_url": "https://api.github.com/users/Yoyo-test-74/gists{/gist_id}",
#           "starred_url": "https://api.github.com/users/Yoyo-test-74/starred{/owner}{/repo}",
#           "subscriptions_url": "https://api.github.com/users/Yoyo-test-74/subscriptions",
#           "organizations_url": "https://api.github.com/users/Yoyo-test-74/orgs",
#           "repos_url": "https://api.github.com/users/Yoyo-test-74/repos",
#           "events_url": "https://api.github.com/users/Yoyo-test-74/events{/privacy}",
#           "received_events_url": "https://api.github.com/users/Yoyo-test-74/received_events",
#           "type": "User",
#           "user_view_type": "public",
#           "site_admin": false
#         },
#         "labels": [],
#         "state": "open",
#         "locked": false,
#         "assignee": null,
#         "assignees": [],
#         "milestone": null,
#         "comments": 3,
#         "created_at": "2025-03-18T02:35:53Z",
#         "updated_at": "2025-03-18T03:53:03Z",
#         "closed_at": null,
#         "author_association": "NONE",
#         "sub_issues_summary": {
#           "total": 0,
#           "completed": 0,
#           "percent_completed": 0
#         },
#         "active_lock_reason": null,
#         "draft": false,
#         "pull_request": {
#           "url": "https://api.github.com/repos/koii-network/prometheus-beta/pulls/8429",
#           "html_url": "https://github.com/koii-network/prometheus-beta/pull/8429",
#           "diff_url": "https://github.com/koii-network/prometheus-beta/pull/8429.diff",
#           "patch_url": "https://github.com/koii-network/prometheus-beta/pull/8429.patch",
#           "merged_at": null
#         },
#         "body": "# Implement JSON Logging Function with Proper Spacing\n\n## Original Task\nWrite a function to log JSON objects with proper spacing\n\n## Summary of Changes\nAdded a new function to enable JSON logging with consistent and readable formatting\n\nThis implementation provides a robust JSON logging mechanism that ensures:\n- Proper indentation of JSON objects\n- Readable and consistent log output\n- Flexibility for different log levels and contexts\n\n## Acceptance Criteria\nAll tests must pass\n\n## Tests\n - Verify JSON logging function creates well-formatted JSON\n - Check that different log levels are supported\n - Ensure no information is lost during JSON conversion\n - Validate handling of nested JSON objects\n",
#         "reactions": {
#           "url": "https://api.github.com/repos/koii-network/prometheus-beta/issues/8429/reactions",
#           "total_count": 0,
#           "+1": 0,
#           "-1": 0,
#           "laugh": 0,
#           "hooray": 0,
#           "confused": 0,
#           "heart": 0,
#           "rocket": 0,
#           "eyes": 0
#         },
#         "timeline_url": "https://api.github.com/repos/koii-network/prometheus-beta/issues/8429/timeline",
#         "performed_via_github_app": null,
#         "state_reason": null
#       },
#       "comment": {
#         "url": "https://api.github.com/repos/koii-network/prometheus-beta/issues/comments/2731543155",
#         "html_url": "https://github.com/koii-network/prometheus-beta/pull/8429#issuecomment-2731543155",
#         "issue_url": "https://api.github.com/repos/koii-network/prometheus-beta/issues/8429",
#         "id": 2731543155,
#         "node_id": "IC_kwDON5RKss6i0Apz",
#         "user": {
#           "login": "VaterOtter",
#           "id": 23240686,
#           "node_id": "MDQ6VXNlcjIzMjQwNjg2",
#           "avatar_url": "https://avatars.githubusercontent.com/u/23240686?v=4",
#           "gravatar_id": "",
#           "url": "https://api.github.com/users/VaterOtter",
#           "html_url": "https://github.com/VaterOtter",
#           "followers_url": "https://api.github.com/users/VaterOtter/followers",
#           "following_url": "https://api.github.com/users/VaterOtter/following{/other_user}",
#           "gists_url": "https://api.github.com/users/VaterOtter/gists{/gist_id}",
#           "starred_url": "https://api.github.com/users/VaterOtter/starred{/owner}{/repo}",
#           "subscriptions_url": "https://api.github.com/users/VaterOtter/subscriptions",
#           "organizations_url": "https://api.github.com/users/VaterOtter/orgs",
#           "repos_url": "https://api.github.com/users/VaterOtter/repos",
#           "events_url": "https://api.github.com/users/VaterOtter/events{/privacy}",
#           "received_events_url": "https://api.github.com/users/VaterOtter/received_events",
#           "type": "User",
#           "user_view_type": "public",
#           "site_admin": false
#         },
#         "created_at": "2025-03-18T03:52:36Z",
#         "updated_at": "2025-03-18T03:52:36Z",
#         "author_association": "NONE",
#         "body": "# PR Review: Unique Grid Paths Implementation\n\n## Recommendation: APPROVE\n\n### Justification\n- Correct implementation of unique grid paths algorithm\n- Comprehensive test suite\n- Proper error handling\n- Clean and efficient solution\n\n## Summary of Changes\nImplemented dynamic programming solution for counting unique paths in a grid\n\n## Requirements Review\n### \u2705 Met Requirements\n- Correct grid paths algorithm\n- Input validation\n- Error handling\n- Follows file organization requirements\n\n### \u274c Unmet Requirements\n*All requirements are met*\n\n## Test Evaluation\n### Coverage\n- Grid dimension tests\n- Standard grid scenarios\n- Edge cases\n- Error handling\n\n### Issues in Existing Tests\n*No issues found in existing tests*\n\n### Missing Test Cases\n*No missing test cases identified*\n\n## Action Items\n- {\n- \n\n-  \n-  \n-  \n-  \n- \"\n- a\n- c\n- t\n- i\n- o\n- n\n- _\n- i\n- t\n- e\n- m\n- s\n- \"\n- :\n-  \n- [\n- ]\n- ,\n-  \n- \n\n-  \n-  \n-  \n-  \n- \"\n- p\n- r\n- _\n- n\n- u\n- m\n- b\n- e\n- r\n- \"\n- :\n-  \n-  \n- 8\n- 4\n- 2\n- 9\n- \n\n- }\n",
#         "reactions": {
#           "url": "https://api.github.com/repos/koii-network/prometheus-beta/issues/comments/2731543155/reactions",
#           "total_count": 0,
#           "+1": 0,
#           "-1": 0,
#           "laugh": 0,
#           "hooray": 0,
#           "confused": 0,
#           "heart": 0,
#           "rocket": 0,
#           "eyes": 0
#         },
#         "performed_via_github_app": null
#       }
#     },
#     "public": true,
#     "created_at": "2025-03-18T03:53:03Z",
#     "org": {
#       "id": 75863118,
#       "login": "koii-network",
#       "gravatar_id": "",
#       "url": "https://api.github.com/orgs/koii-network",
#       "avatar_url": "https://avatars.githubusercontent.com/u/75863118?"
#     }
#   },
#   {
#     "id": "47666338112",
#     "type": "PushEvent",
#     "actor": {
#       "id": 41898282,
#       "login": "github-actions[bot]",
#       "display_login": "github-actions",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/github-actions[bot]",
#       "avatar_url": "https://avatars.githubusercontent.com/u/41898282?"
#     },
#     "repo": {
#       "id": 802914651,
#       "name": "mooncat77/lava",
#       "url": "https://api.github.com/repos/mooncat77/lava"
#     },
#     "payload": {
#       "repository_id": 802914651,
#       "push_id": 23228177683,
#       "size": 1,
#       "distinct_size": 1,
#       "ref": "refs/heads/master",
#       "head": "acca4c30f7a0bb34c966e70ce6c992484bbcfa95",
#       "before": "52cffd9cc9b536c324dae651116301707bbaf323",
#       "commits": [
#         {
#           "sha": "acca4c30f7a0bb34c966e70ce6c992484bbcfa95",
#           "author": {
#             "email": "rxmxdhxni@gmail.com",
#             "name": "dante4rt"
#           },
#           "message": "\ud83d\udd25 Hotfix StarkNet network",
#           "distinct": true,
#           "url": "https://api.github.com/repos/mooncat77/lava/commits/acca4c30f7a0bb34c966e70ce6c992484bbcfa95"
#         }
#       ]
#     },
#     "public": true,
#     "created_at": "2025-03-18T03:53:03Z"
#   },
#   {
#     "id": "47666338120",
#     "type": "PullRequestEvent",
#     "actor": {
#       "id": 104101892,
#       "login": "pixeebot[bot]",
#       "display_login": "pixeebot",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/pixeebot[bot]",
#       "avatar_url": "https://avatars.githubusercontent.com/u/104101892?"
#     },
#     "repo": {
#       "id": 918304041,
#       "name": "browser-vm/MetaGPT",
#       "url": "https://api.github.com/repos/browser-vm/MetaGPT"
#     },
#     "payload": {
#       "action": "opened",
#       "number": 5,
#       "pull_request": {
#         "url": "https://api.github.com/repos/browser-vm/MetaGPT/pulls/5",
#         "id": 2399631153,
#         "node_id": "PR_kwDONrw1Kc6PB3cx",
#         "html_url": "https://github.com/browser-vm/MetaGPT/pull/5",
#         "diff_url": "https://github.com/browser-vm/MetaGPT/pull/5.diff",
#         "patch_url": "https://github.com/browser-vm/MetaGPT/pull/5.patch",
#         "issue_url": "https://api.github.com/repos/browser-vm/MetaGPT/issues/5",
#         "number": 5,
#         "state": "open",
#         "locked": false,
#         "title": "Use `defusedxml` for Parsing XML",
#         "user": {
#           "login": "pixeebot[bot]",
#           "id": 104101892,
#           "node_id": "BOT_kgDOBjR4BA",
#           "avatar_url": "https://avatars.githubusercontent.com/in/193111?v=4",
#           "gravatar_id": "",
#           "url": "https://api.github.com/users/pixeebot%5Bbot%5D",
#           "html_url": "https://github.com/apps/pixeebot",
#           "followers_url": "https://api.github.com/users/pixeebot%5Bbot%5D/followers",
#           "following_url": "https://api.github.com/users/pixeebot%5Bbot%5D/following{/other_user}",
#           "gists_url": "https://api.github.com/users/pixeebot%5Bbot%5D/gists{/gist_id}",
#           "starred_url": "https://api.github.com/users/pixeebot%5Bbot%5D/starred{/owner}{/repo}",
#           "subscriptions_url": "https://api.github.com/users/pixeebot%5Bbot%5D/subscriptions",
#           "organizations_url": "https://api.github.com/users/pixeebot%5Bbot%5D/orgs",
#           "repos_url": "https://api.github.com/users/pixeebot%5Bbot%5D/repos",
#           "events_url": "https://api.github.com/users/pixeebot%5Bbot%5D/events{/privacy}",
#           "received_events_url": "https://api.github.com/users/pixeebot%5Bbot%5D/received_events",
#           "type": "Bot",
#           "user_view_type": "public",
#           "site_admin": false
#         },
#         "body": "You might be surprised to learn that Python's built-in XML libraries are [considered insecure](https://docs.python.org/3/library/xml.html#xml-vulnerabilities) against various kinds of attacks.\n\nIn fact, the [Python documentation itself](https://docs.python.org/3/library/xml.html#the-defusedxml-package) recommends the use of [defusedxml](https://pypi.org/project/defusedxml/) for parsing untrusted XML data. `defusedxml` is an [open-source](https://github.com/tiran/defusedxml), permissively licensed project that is intended as a drop-in replacement for Python's standard library XML parsers.\n\nThis codemod updates all relevant uses of the standard library parsers with safe versions from `defusedxml`. It also adds the `defusedxml` dependency to your project where possible.\n\nThe changes from this codemod look like this:\n```diff\n- from xml.etree.ElementTree import parse\n+ import defusedxml.ElementTree\n\n- et = parse('data.xml')\n+ et = defusedxml.ElementTree.parse('data.xml')\n```\n\n## Dependency Updates\n\nThis codemod relies on an external dependency. We have automatically added this dependency to your project's `requirements.txt` file. \n\nThis package is [recommended by the Python community](https://docs.python.org/3/library/xml.html#the-defusedxml-package) to protect against XML vulnerabilities. \n\nThere are a number of places where Python project dependencies can be expressed, including `setup.py`, `pyproject.toml`, `setup.cfg`, and `requirements.txt` files. If this change is incorrect, or if you are using another packaging system such as `poetry`, it may be necessary for you to manually add the dependency to the proper location in your project.\n\n<details>\n  <summary>More reading</summary>\n\n  * [https://docs.python.org/3/library/xml.html#xml-vulnerabilities](https://docs.python.org/3/library/xml.html#xml-vulnerabilities)\n  * [https://docs.python.org/3/library/xml.html#the-defusedxml-package](https://docs.python.org/3/library/xml.html#the-defusedxml-package)\n  * [https://pypi.org/project/defusedxml/](https://pypi.org/project/defusedxml/)\n  * [https://cheatsheetseries.owasp.org/cheatsheets/XML_External_Entity_Prevention_Cheat_Sheet.html](https://cheatsheetseries.owasp.org/cheatsheets/XML_External_Entity_Prevention_Cheat_Sheet.html)\n  * [https://cwe.mitre.org/data/definitions/611](https://cwe.mitre.org/data/definitions/611)\n</details>\n\nI have additional improvements ready for this repo! If you want to see them, leave the comment:\n```\n@pixeebot next\n```\n... and I will open a new PR right away!\n\n\n\ud83e\uddda\ud83e\udd16  Powered by Pixeebot  \n\n[Feedback](https://ask.pixee.ai/feedback) | [Community](https://pixee-community.slack.com/signup#/domain-signup) | [Docs](https://docs.pixee.ai/) | Codemod ID: pixee:python/use-defusedxml ![](https://d1zaessa2hpsmj.cloudfront.net/pixel/v1/track?writeKey=2PI43jNm7atYvAuK7rJUz3Kcd6A&event=DRIP_PR%7Cbrowser-vm%2FMetaGPT%7C402d81b29bfebdd61c77b09d9489ff11fd5e89cf)\n\n\n<!--{\"type\":\"DRIP\",\"codemod\":\"pixee:python/use-defusedxml\"}-->",
#         "created_at": "2025-03-18T03:52:36Z",
#         "updated_at": "2025-03-18T03:52:36Z",
#         "closed_at": null,
#         "merged_at": null,
#         "merge_commit_sha": "0e5b25298db082a942ca91bdc2fbb357f4ecd6aa",
#         "assignee": null,
#         "assignees": [],
#         "requested_reviewers": [],
#         "requested_teams": [],
#         "labels": [],
#         "milestone": null,
#         "draft": false,
#         "commits_url": "https://api.github.com/repos/browser-vm/MetaGPT/pulls/5/commits",
#         "review_comments_url": "https://api.github.com/repos/browser-vm/MetaGPT/pulls/5/comments",
#         "review_comment_url": "https://api.github.com/repos/browser-vm/MetaGPT/pulls/comments{/number}",
#         "comments_url": "https://api.github.com/repos/browser-vm/MetaGPT/issues/5/comments",
#         "statuses_url": "https://api.github.com/repos/browser-vm/MetaGPT/statuses/402d81b29bfebdd61c77b09d9489ff11fd5e89cf",
#         "head": {
#           "label": "browser-vm:pixeebot/drip-2025-03-18-pixee-python/use-defusedxml",
#           "ref": "pixeebot/drip-2025-03-18-pixee-python/use-defusedxml",
#           "sha": "402d81b29bfebdd61c77b09d9489ff11fd5e89cf",
#           "user": {
#             "login": "browser-vm",
#             "id": 195449322,
#             "node_id": "U_kgDOC6ZR6g",
#             "avatar_url": "https://avatars.githubusercontent.com/u/195449322?v=4",
#             "gravatar_id": "",
#             "url": "https://api.github.com/users/browser-vm",
#             "html_url": "https://github.com/browser-vm",
#             "followers_url": "https://api.github.com/users/browser-vm/followers",
#             "following_url": "https://api.github.com/users/browser-vm/following{/other_user}",
#             "gists_url": "https://api.github.com/users/browser-vm/gists{/gist_id}",
#             "starred_url": "https://api.github.com/users/browser-vm/starred{/owner}{/repo}",
#             "subscriptions_url": "https://api.github.com/users/browser-vm/subscriptions",
#             "organizations_url": "https://api.github.com/users/browser-vm/orgs",
#             "repos_url": "https://api.github.com/users/browser-vm/repos",
#             "events_url": "https://api.github.com/users/browser-vm/events{/privacy}",
#             "received_events_url": "https://api.github.com/users/browser-vm/received_events",
#             "type": "User",
#             "user_view_type": "public",
#             "site_admin": false
#           },
#           "repo": {
#             "id": 918304041,
#             "node_id": "R_kgDONrw1KQ",
#             "name": "MetaGPT",
#             "full_name": "browser-vm/MetaGPT",
#             "private": false,
#             "owner": {
#               "login": "browser-vm",
#               "id": 195449322,
#               "node_id": "U_kgDOC6ZR6g",
#               "avatar_url": "https://avatars.githubusercontent.com/u/195449322?v=4",
#               "gravatar_id": "",
#               "url": "https://api.github.com/users/browser-vm",
#               "html_url": "https://github.com/browser-vm",
#               "followers_url": "https://api.github.com/users/browser-vm/followers",
#               "following_url": "https://api.github.com/users/browser-vm/following{/other_user}",
#               "gists_url": "https://api.github.com/users/browser-vm/gists{/gist_id}",
#               "starred_url": "https://api.github.com/users/browser-vm/starred{/owner}{/repo}",
#               "subscriptions_url": "https://api.github.com/users/browser-vm/subscriptions",
#               "organizations_url": "https://api.github.com/users/browser-vm/orgs",
#               "repos_url": "https://api.github.com/users/browser-vm/repos",
#               "events_url": "https://api.github.com/users/browser-vm/events{/privacy}",
#               "received_events_url": "https://api.github.com/users/browser-vm/received_events",
#               "type": "User",
#               "user_view_type": "public",
#               "site_admin": false
#             },
#             "html_url": "https://github.com/browser-vm/MetaGPT",
#             "description": "\ud83c\udf1f The Multi-Agent Framework: First AI Software Company, Towards Natural Language Programming",
#             "fork": true,
#             "url": "https://api.github.com/repos/browser-vm/MetaGPT",
#             "forks_url": "https://api.github.com/repos/browser-vm/MetaGPT/forks",
#             "keys_url": "https://api.github.com/repos/browser-vm/MetaGPT/keys{/key_id}",
#             "collaborators_url": "https://api.github.com/repos/browser-vm/MetaGPT/collaborators{/collaborator}",
#             "teams_url": "https://api.github.com/repos/browser-vm/MetaGPT/teams",
#             "hooks_url": "https://api.github.com/repos/browser-vm/MetaGPT/hooks",
#             "issue_events_url": "https://api.github.com/repos/browser-vm/MetaGPT/issues/events{/number}",
#             "events_url": "https://api.github.com/repos/browser-vm/MetaGPT/events",
#             "assignees_url": "https://api.github.com/repos/browser-vm/MetaGPT/assignees{/user}",
#             "branches_url": "https://api.github.com/repos/browser-vm/MetaGPT/branches{/branch}",
#             "tags_url": "https://api.github.com/repos/browser-vm/MetaGPT/tags",
#             "blobs_url": "https://api.github.com/repos/browser-vm/MetaGPT/git/blobs{/sha}",
#             "git_tags_url": "https://api.github.com/repos/browser-vm/MetaGPT/git/tags{/sha}",
#             "git_refs_url": "https://api.github.com/repos/browser-vm/MetaGPT/git/refs{/sha}",
#             "trees_url": "https://api.github.com/repos/browser-vm/MetaGPT/git/trees{/sha}",
#             "statuses_url": "https://api.github.com/repos/browser-vm/MetaGPT/statuses/{sha}",
#             "languages_url": "https://api.github.com/repos/browser-vm/MetaGPT/languages",
#             "stargazers_url": "https://api.github.com/repos/browser-vm/MetaGPT/stargazers",
#             "contributors_url": "https://api.github.com/repos/browser-vm/MetaGPT/contributors",
#             "subscribers_url": "https://api.github.com/repos/browser-vm/MetaGPT/subscribers",
#             "subscription_url": "https://api.github.com/repos/browser-vm/MetaGPT/subscription",
#             "commits_url": "https://api.github.com/repos/browser-vm/MetaGPT/commits{/sha}",
#             "git_commits_url": "https://api.github.com/repos/browser-vm/MetaGPT/git/commits{/sha}",
#             "comments_url": "https://api.github.com/repos/browser-vm/MetaGPT/comments{/number}",
#             "issue_comment_url": "https://api.github.com/repos/browser-vm/MetaGPT/issues/comments{/number}",
#             "contents_url": "https://api.github.com/repos/browser-vm/MetaGPT/contents/{+path}",
#             "compare_url": "https://api.github.com/repos/browser-vm/MetaGPT/compare/{base}...{head}",
#             "merges_url": "https://api.github.com/repos/browser-vm/MetaGPT/merges",
#             "archive_url": "https://api.github.com/repos/browser-vm/MetaGPT/{archive_format}{/ref}",
#             "downloads_url": "https://api.github.com/repos/browser-vm/MetaGPT/downloads",
#             "issues_url": "https://api.github.com/repos/browser-vm/MetaGPT/issues{/number}",
#             "pulls_url": "https://api.github.com/repos/browser-vm/MetaGPT/pulls{/number}",
#             "milestones_url": "https://api.github.com/repos/browser-vm/MetaGPT/milestones{/number}",
#             "notifications_url": "https://api.github.com/repos/browser-vm/MetaGPT/notifications{?since,all,participating}",
#             "labels_url": "https://api.github.com/repos/browser-vm/MetaGPT/labels{/name}",
#             "releases_url": "https://api.github.com/repos/browser-vm/MetaGPT/releases{/id}",
#             "deployments_url": "https://api.github.com/repos/browser-vm/MetaGPT/deployments",
#             "created_at": "2025-01-17T16:52:01Z",
#             "updated_at": "2025-02-07T12:38:46Z",
#             "pushed_at": "2025-03-18T03:52:35Z",
#             "git_url": "git://github.com/browser-vm/MetaGPT.git",
#             "ssh_url": "git@github.com:browser-vm/MetaGPT.git",
#             "clone_url": "https://github.com/browser-vm/MetaGPT.git",
#             "svn_url": "https://github.com/browser-vm/MetaGPT",
#             "homepage": "https://deepwisdom.ai/",
#             "size": 75431,
#             "stargazers_count": 0,
#             "watchers_count": 0,
#             "language": "Python",
#             "has_issues": false,
#             "has_projects": true,
#             "has_downloads": true,
#             "has_wiki": true,
#             "has_pages": false,
#             "has_discussions": false,
#             "forks_count": 0,
#             "mirror_url": null,
#             "archived": false,
#             "disabled": false,
#             "open_issues_count": 2,
#             "license": {
#               "key": "mit",
#               "name": "MIT License",
#               "spdx_id": "MIT",
#               "url": "https://api.github.com/licenses/mit",
#               "node_id": "MDc6TGljZW5zZTEz"
#             },
#             "allow_forking": true,
#             "is_template": false,
#             "web_commit_signoff_required": false,
#             "topics": [],
#             "visibility": "public",
#             "forks": 0,
#             "open_issues": 2,
#             "watchers": 0,
#             "default_branch": "main"
#           }
#         },
#         "base": {
#           "label": "browser-vm:main",
#           "ref": "main",
#           "sha": "e7879ff868ac6dafdd3a9666903e5dbe8e473429",
#           "user": {
#             "login": "browser-vm",
#             "id": 195449322,
#             "node_id": "U_kgDOC6ZR6g",
#             "avatar_url": "https://avatars.githubusercontent.com/u/195449322?v=4",
#             "gravatar_id": "",
#             "url": "https://api.github.com/users/browser-vm",
#             "html_url": "https://github.com/browser-vm",
#             "followers_url": "https://api.github.com/users/browser-vm/followers",
#             "following_url": "https://api.github.com/users/browser-vm/following{/other_user}",
#             "gists_url": "https://api.github.com/users/browser-vm/gists{/gist_id}",
#             "starred_url": "https://api.github.com/users/browser-vm/starred{/owner}{/repo}",
#             "subscriptions_url": "https://api.github.com/users/browser-vm/subscriptions",
#             "organizations_url": "https://api.github.com/users/browser-vm/orgs",
#             "repos_url": "https://api.github.com/users/browser-vm/repos",
#             "events_url": "https://api.github.com/users/browser-vm/events{/privacy}",
#             "received_events_url": "https://api.github.com/users/browser-vm/received_events",
#             "type": "User",
#             "user_view_type": "public",
#             "site_admin": false
#           },
#           "repo": {
#             "id": 918304041,
#             "node_id": "R_kgDONrw1KQ",
#             "name": "MetaGPT",
#             "full_name": "browser-vm/MetaGPT",
#             "private": false,
#             "owner": {
#               "login": "browser-vm",
#               "id": 195449322,
#               "node_id": "U_kgDOC6ZR6g",
#               "avatar_url": "https://avatars.githubusercontent.com/u/195449322?v=4",
#               "gravatar_id": "",
#               "url": "https://api.github.com/users/browser-vm",
#               "html_url": "https://github.com/browser-vm",
#               "followers_url": "https://api.github.com/users/browser-vm/followers",
#               "following_url": "https://api.github.com/users/browser-vm/following{/other_user}",
#               "gists_url": "https://api.github.com/users/browser-vm/gists{/gist_id}",
#               "starred_url": "https://api.github.com/users/browser-vm/starred{/owner}{/repo}",
#               "subscriptions_url": "https://api.github.com/users/browser-vm/subscriptions",
#               "organizations_url": "https://api.github.com/users/browser-vm/orgs",
#               "repos_url": "https://api.github.com/users/browser-vm/repos",
#               "events_url": "https://api.github.com/users/browser-vm/events{/privacy}",
#               "received_events_url": "https://api.github.com/users/browser-vm/received_events",
#               "type": "User",
#               "user_view_type": "public",
#               "site_admin": false
#             },
#             "html_url": "https://github.com/browser-vm/MetaGPT",
#             "description": "\ud83c\udf1f The Multi-Agent Framework: First AI Software Company, Towards Natural Language Programming",
#             "fork": true,
#             "url": "https://api.github.com/repos/browser-vm/MetaGPT",
#             "forks_url": "https://api.github.com/repos/browser-vm/MetaGPT/forks",
#             "keys_url": "https://api.github.com/repos/browser-vm/MetaGPT/keys{/key_id}",
#             "collaborators_url": "https://api.github.com/repos/browser-vm/MetaGPT/collaborators{/collaborator}",
#             "teams_url": "https://api.github.com/repos/browser-vm/MetaGPT/teams",
#             "hooks_url": "https://api.github.com/repos/browser-vm/MetaGPT/hooks",
#             "issue_events_url": "https://api.github.com/repos/browser-vm/MetaGPT/issues/events{/number}",
#             "events_url": "https://api.github.com/repos/browser-vm/MetaGPT/events",
#             "assignees_url": "https://api.github.com/repos/browser-vm/MetaGPT/assignees{/user}",
#             "branches_url": "https://api.github.com/repos/browser-vm/MetaGPT/branches{/branch}",
#             "tags_url": "https://api.github.com/repos/browser-vm/MetaGPT/tags",
#             "blobs_url": "https://api.github.com/repos/browser-vm/MetaGPT/git/blobs{/sha}",
#             "git_tags_url": "https://api.github.com/repos/browser-vm/MetaGPT/git/tags{/sha}",
#             "git_refs_url": "https://api.github.com/repos/browser-vm/MetaGPT/git/refs{/sha}",
#             "trees_url": "https://api.github.com/repos/browser-vm/MetaGPT/git/trees{/sha}",
#             "statuses_url": "https://api.github.com/repos/browser-vm/MetaGPT/statuses/{sha}",
#             "languages_url": "https://api.github.com/repos/browser-vm/MetaGPT/languages",
#             "stargazers_url": "https://api.github.com/repos/browser-vm/MetaGPT/stargazers",
#             "contributors_url": "https://api.github.com/repos/browser-vm/MetaGPT/contributors",
#             "subscribers_url": "https://api.github.com/repos/browser-vm/MetaGPT/subscribers",
#             "subscription_url": "https://api.github.com/repos/browser-vm/MetaGPT/subscription",
#             "commits_url": "https://api.github.com/repos/browser-vm/MetaGPT/commits{/sha}",
#             "git_commits_url": "https://api.github.com/repos/browser-vm/MetaGPT/git/commits{/sha}",
#             "comments_url": "https://api.github.com/repos/browser-vm/MetaGPT/comments{/number}",
#             "issue_comment_url": "https://api.github.com/repos/browser-vm/MetaGPT/issues/comments{/number}",
#             "contents_url": "https://api.github.com/repos/browser-vm/MetaGPT/contents/{+path}",
#             "compare_url": "https://api.github.com/repos/browser-vm/MetaGPT/compare/{base}...{head}",
#             "merges_url": "https://api.github.com/repos/browser-vm/MetaGPT/merges",
#             "archive_url": "https://api.github.com/repos/browser-vm/MetaGPT/{archive_format}{/ref}",
#             "downloads_url": "https://api.github.com/repos/browser-vm/MetaGPT/downloads",
#             "issues_url": "https://api.github.com/repos/browser-vm/MetaGPT/issues{/number}",
#             "pulls_url": "https://api.github.com/repos/browser-vm/MetaGPT/pulls{/number}",
#             "milestones_url": "https://api.github.com/repos/browser-vm/MetaGPT/milestones{/number}",
#             "notifications_url": "https://api.github.com/repos/browser-vm/MetaGPT/notifications{?since,all,participating}",
#             "labels_url": "https://api.github.com/repos/browser-vm/MetaGPT/labels{/name}",
#             "releases_url": "https://api.github.com/repos/browser-vm/MetaGPT/releases{/id}",
#             "deployments_url": "https://api.github.com/repos/browser-vm/MetaGPT/deployments",
#             "created_at": "2025-01-17T16:52:01Z",
#             "updated_at": "2025-02-07T12:38:46Z",
#             "pushed_at": "2025-03-18T03:52:35Z",
#             "git_url": "git://github.com/browser-vm/MetaGPT.git",
#             "ssh_url": "git@github.com:browser-vm/MetaGPT.git",
#             "clone_url": "https://github.com/browser-vm/MetaGPT.git",
#             "svn_url": "https://github.com/browser-vm/MetaGPT",
#             "homepage": "https://deepwisdom.ai/",
#             "size": 75431,
#             "stargazers_count": 0,
#             "watchers_count": 0,
#             "language": "Python",
#             "has_issues": false,
#             "has_projects": true,
#             "has_downloads": true,
#             "has_wiki": true,
#             "has_pages": false,
#             "has_discussions": false,
#             "forks_count": 0,
#             "mirror_url": null,
#             "archived": false,
#             "disabled": false,
#             "open_issues_count": 2,
#             "license": {
#               "key": "mit",
#               "name": "MIT License",
#               "spdx_id": "MIT",
#               "url": "https://api.github.com/licenses/mit",
#               "node_id": "MDc6TGljZW5zZTEz"
#             },
#             "allow_forking": true,
#             "is_template": false,
#             "web_commit_signoff_required": false,
#             "topics": [],
#             "visibility": "public",
#             "forks": 0,
#             "open_issues": 2,
#             "watchers": 0,
#             "default_branch": "main"
#           }
#         },
#         "_links": {
#           "self": {
#             "href": "https://api.github.com/repos/browser-vm/MetaGPT/pulls/5"
#           },
#           "html": {
#             "href": "https://github.com/browser-vm/MetaGPT/pull/5"
#           },
#           "issue": {
#             "href": "https://api.github.com/repos/browser-vm/MetaGPT/issues/5"
#           },
#           "comments": {
#             "href": "https://api.github.com/repos/browser-vm/MetaGPT/issues/5/comments"
#           },
#           "review_comments": {
#             "href": "https://api.github.com/repos/browser-vm/MetaGPT/pulls/5/comments"
#           },
#           "review_comment": {
#             "href": "https://api.github.com/repos/browser-vm/MetaGPT/pulls/comments{/number}"
#           },
#           "commits": {
#             "href": "https://api.github.com/repos/browser-vm/MetaGPT/pulls/5/commits"
#           },
#           "statuses": {
#             "href": "https://api.github.com/repos/browser-vm/MetaGPT/statuses/402d81b29bfebdd61c77b09d9489ff11fd5e89cf"
#           }
#         },
#         "author_association": "NONE",
#         "auto_merge": null,
#         "active_lock_reason": null,
#         "merged": false,
#         "mergeable": true,
#         "rebaseable": true,
#         "mergeable_state": "clean",
#         "merged_by": null,
#         "comments": 0,
#         "review_comments": 1,
#         "maintainer_can_modify": false,
#         "commits": 1,
#         "additions": 4,
#         "deletions": 2,
#         "changed_files": 2
#       }
#     },
#     "public": true,
#     "created_at": "2025-03-18T03:53:03Z"
#   },
#   {
#     "id": "47666338118",
#     "type": "PushEvent",
#     "actor": {
#       "id": 189012340,
#       "login": "Nsrow2510",
#       "display_login": "Nsrow2510",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/Nsrow2510",
#       "avatar_url": "https://avatars.githubusercontent.com/u/189012340?"
#     },
#     "repo": {
#       "id": 919816962,
#       "name": "Nsrow2510/Code-Radar-Solutions",
#       "url": "https://api.github.com/repos/Nsrow2510/Code-Radar-Solutions"
#     },
#     "payload": {
#       "repository_id": 919816962,
#       "push_id": 23228177688,
#       "size": 1,
#       "distinct_size": 1,
#       "ref": "refs/heads/main",
#       "head": "1781a26123f4978f10b67478cec87bca13a48e70",
#       "before": "49e88ef68a531402a02f1ef032e550ce942ae57f",
#       "commits": [
#         {
#           "sha": "1781a26123f4978f10b67478cec87bca13a48e70",
#           "author": {
#             "email": "navneetsrow@gmail.com",
#             "name": "Nsrow2510"
#           },
#           "message": "Solution to Print a Palindromic Number Triangle",
#           "distinct": true,
#           "url": "https://api.github.com/repos/Nsrow2510/Code-Radar-Solutions/commits/1781a26123f4978f10b67478cec87bca13a48e70"
#         }
#       ]
#     },
#     "public": true,
#     "created_at": "2025-03-18T03:53:03Z"
#   },
#   {
#     "id": "47666338114",
#     "type": "CommitCommentEvent",
#     "actor": {
#       "id": 35613825,
#       "login": "vercel[bot]",
#       "display_login": "vercel",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/vercel[bot]",
#       "avatar_url": "https://avatars.githubusercontent.com/u/35613825?"
#     },
#     "repo": {
#       "id": 922035033,
#       "name": "Krishim5802/stock_analysis",
#       "url": "https://api.github.com/repos/Krishim5802/stock_analysis"
#     },
#     "payload": {
#       "comment": {
#         "url": "https://api.github.com/repos/Krishim5802/stock_analysis/comments/153880778",
#         "html_url": "https://github.com/Krishim5802/stock_analysis/commit/a48810a3f4e07a815ede3b181274bfdb181cdf80#commitcomment-153880778",
#         "id": 153880778,
#         "node_id": "CC_kwDONvUjWc4JLAjK",
#         "user": {
#           "login": "vercel[bot]",
#           "id": 35613825,
#           "node_id": "MDM6Qm90MzU2MTM4MjU=",
#           "avatar_url": "https://avatars.githubusercontent.com/in/8329?v=4",
#           "gravatar_id": "",
#           "url": "https://api.github.com/users/vercel%5Bbot%5D",
#           "html_url": "https://github.com/apps/vercel",
#           "followers_url": "https://api.github.com/users/vercel%5Bbot%5D/followers",
#           "following_url": "https://api.github.com/users/vercel%5Bbot%5D/following{/other_user}",
#           "gists_url": "https://api.github.com/users/vercel%5Bbot%5D/gists{/gist_id}",
#           "starred_url": "https://api.github.com/users/vercel%5Bbot%5D/starred{/owner}{/repo}",
#           "subscriptions_url": "https://api.github.com/users/vercel%5Bbot%5D/subscriptions",
#           "organizations_url": "https://api.github.com/users/vercel%5Bbot%5D/orgs",
#           "repos_url": "https://api.github.com/users/vercel%5Bbot%5D/repos",
#           "events_url": "https://api.github.com/users/vercel%5Bbot%5D/events{/privacy}",
#           "received_events_url": "https://api.github.com/users/vercel%5Bbot%5D/received_events",
#           "type": "Bot",
#           "user_view_type": "public",
#           "site_admin": false
#         },
#         "position": null,
#         "line": null,
#         "path": null,
#         "commit_id": "a48810a3f4e07a815ede3b181274bfdb181cdf80",
#         "created_at": "2025-03-18T03:53:02Z",
#         "updated_at": "2025-03-18T03:53:02Z",
#         "author_association": "NONE",
#         "body": "Successfully deployed to the following URLs:\n\n## stock-analysis \u2013 ./\n\n[stock-analysis-krishims-projects.vercel.app](https://stock-analysis-krishims-projects.vercel.app)  \n[stock-analysis-git-main-krishims-projects.vercel.app](https://stock-analysis-git-main-krishims-projects.vercel.app)  \n[gptpivot.com](https://gptpivot.com)  \n[www.gptpivot.com](https://www.gptpivot.com)  \n[stock-analysis-liard.vercel.app](https://stock-analysis-liard.vercel.app)",
#         "reactions": {
#           "url": "https://api.github.com/repos/Krishim5802/stock_analysis/comments/153880778/reactions",
#           "total_count": 0,
#           "+1": 0,
#           "-1": 0,
#           "laugh": 0,
#           "hooray": 0,
#           "confused": 0,
#           "heart": 0,
#           "rocket": 0,
#           "eyes": 0
#         }
#       }
#     },
#     "public": true,
#     "created_at": "2025-03-18T03:53:02Z"
#   },
#   {
#     "id": "47666338122",
#     "type": "IssuesEvent",
#     "actor": {
#       "id": 4582016,
#       "login": "GermanBluefox",
#       "display_login": "GermanBluefox",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/GermanBluefox",
#       "avatar_url": "https://avatars.githubusercontent.com/u/4582016?"
#     },
#     "repo": {
#       "id": 779225992,
#       "name": "rg-engineering/ioBroker.vis-2-widgets-weather-and-heating",
#       "url": "https://api.github.com/repos/rg-engineering/ioBroker.vis-2-widgets-weather-and-heating"
#     },
#     "payload": {
#       "action": "opened",
#       "issue": {
#         "url": "https://api.github.com/repos/rg-engineering/ioBroker.vis-2-widgets-weather-and-heating/issues/76",
#         "repository_url": "https://api.github.com/repos/rg-engineering/ioBroker.vis-2-widgets-weather-and-heating",
#         "labels_url": "https://api.github.com/repos/rg-engineering/ioBroker.vis-2-widgets-weather-and-heating/issues/76/labels{/name}",
#         "comments_url": "https://api.github.com/repos/rg-engineering/ioBroker.vis-2-widgets-weather-and-heating/issues/76/comments",
#         "events_url": "https://api.github.com/repos/rg-engineering/ioBroker.vis-2-widgets-weather-and-heating/issues/76/events",
#         "html_url": "https://github.com/rg-engineering/ioBroker.vis-2-widgets-weather-and-heating/issues/76",
#         "id": 2927023574,
#         "node_id": "I_kwDOLnILiM6udtXW",
#         "number": 76,
#         "title": "Update stable version in repo from 0.9.1 to 0.10.0",
#         "user": {
#           "login": "GermanBluefox",
#           "id": 4582016,
#           "node_id": "MDQ6VXNlcjQ1ODIwMTY=",
#           "avatar_url": "https://avatars.githubusercontent.com/u/4582016?v=4",
#           "gravatar_id": "",
#           "url": "https://api.github.com/users/GermanBluefox",
#           "html_url": "https://github.com/GermanBluefox",
#           "followers_url": "https://api.github.com/users/GermanBluefox/followers",
#           "following_url": "https://api.github.com/users/GermanBluefox/following{/other_user}",
#           "gists_url": "https://api.github.com/users/GermanBluefox/gists{/gist_id}",
#           "starred_url": "https://api.github.com/users/GermanBluefox/starred{/owner}{/repo}",
#           "subscriptions_url": "https://api.github.com/users/GermanBluefox/subscriptions",
#           "organizations_url": "https://api.github.com/users/GermanBluefox/orgs",
#           "repos_url": "https://api.github.com/users/GermanBluefox/repos",
#           "events_url": "https://api.github.com/users/GermanBluefox/events{/privacy}",
#           "received_events_url": "https://api.github.com/users/GermanBluefox/received_events",
#           "type": "User",
#           "user_view_type": "public",
#           "site_admin": false
#         },
#         "labels": [],
#         "state": "open",
#         "locked": false,
#         "assignee": null,
#         "assignees": [],
#         "milestone": null,
#         "comments": 0,
#         "created_at": "2025-03-18T03:52:38Z",
#         "updated_at": "2025-03-18T03:52:38Z",
#         "closed_at": null,
#         "author_association": "CONTRIBUTOR",
#         "sub_issues_summary": {
#           "total": 0,
#           "completed": 0,
#           "percent_completed": 0
#         },
#         "active_lock_reason": null,
#         "body": "# Think about update stable version to 0.10.0\n**Version**: stable=**0.9.1** (64 days old) => latest=**0.10.0** (15 days old)\n**Installs**: stable=**305** (49.11%), latest=**155** (24.96%), total=**621**\n\nClick to use [developer portal](https://www.iobroker.dev/adapter/vis-2-widgets-weather-and-heating/releases)\nClick to [edit](https://github.com/ioBroker/ioBroker.repositories/edit/master/sources-dist-stable.json#L2910)\n\n**Do not close this issue manually as a new issue will be created if condition for update still exists.**\n\nPlease drop a comment if any reason exists which blocks updating to version 0.10.0 at this time.\n\n\nNote: This is an automatically generated message and not personally authored by bluefox!\n      @mcm1957 for evidence",
#         "reactions": {
#           "url": "https://api.github.com/repos/rg-engineering/ioBroker.vis-2-widgets-weather-and-heating/issues/76/reactions",
#           "total_count": 0,
#           "+1": 0,
#           "-1": 0,
#           "laugh": 0,
#           "hooray": 0,
#           "confused": 0,
#           "heart": 0,
#           "rocket": 0,
#           "eyes": 0
#         },
#         "timeline_url": "https://api.github.com/repos/rg-engineering/ioBroker.vis-2-widgets-weather-and-heating/issues/76/timeline",
#         "performed_via_github_app": null,
#         "state_reason": null
#       }
#     },
#     "public": true,
#     "created_at": "2025-03-18T03:53:03Z"
#   },
#   {
#     "id": "47666338116",
#     "type": "IssueCommentEvent",
#     "actor": {
#       "id": 16657278,
#       "login": "sebastien-rosset",
#       "display_login": "sebastien-rosset",
#       "gravatar_id": "",
# ...
#             "git_url": "git://github.com/ac-i2i-engineering/resumax.git",
#             "ssh_url": "git@github.com:ac-i2i-engineering/resumax.git",
#             "clone_url": "https://github.com/ac-i2i-engineering/resumax.git",
#             "svn_url": "https://github.com/ac-i2i-engineering/resumax",
#             "homepage": null,
#             "size": 779,
#             "stargazers_count": 0,
#             "watchers_count": 0,
#             "language": "Python",
#             "has_issues": true,
#             "has_projects": true,
#             "has_downloads": true,
#             "has_wiki": true,
#             "has_pages": false,
#             "has_discussions": false,
#             "forks_count": 0,
#             "mirror_url": null,
#             "archived": false,
#             "disabled": false,
#             "open_issues_count": 1,
#             "license": {
#               "key": "mit",
#               "name": "MIT License",
#               "spdx_id": "MIT",
#               "url": "https://api.github.com/licenses/mit",
#               "node_id": "MDc6TGljZW5zZTEz"
#             },
#             "allow_forking": true,
#             "is_template": false,
#             "web_commit_signoff_required": false,
#             "topics": [],
#             "visibility": "public",
#             "forks": 0,
#             "open_issues": 1,
#             "watchers": 0,
#             "default_branch": "main"
#           }
#         },
#         "base": {
#           "label": "ac-i2i-engineering:main",
#           "ref": "main",
#           "sha": "d7c5787aff3ee18054f8f1f667cd19251afbdf66",
#           "user": {
#             "login": "ac-i2i-engineering",
#             "id": 171437024,
#             "node_id": "O_kgDOCjfr4A",
#             "avatar_url": "https://avatars.githubusercontent.com/u/171437024?v=4",
#             "gravatar_id": "",
#             "url": "https://api.github.com/users/ac-i2i-engineering",
#             "html_url": "https://github.com/ac-i2i-engineering",
#             "followers_url": "https://api.github.com/users/ac-i2i-engineering/followers",
#             "following_url": "https://api.github.com/users/ac-i2i-engineering/following{/other_user}",
#             "gists_url": "https://api.github.com/users/ac-i2i-engineering/gists{/gist_id}",
#             "starred_url": "https://api.github.com/users/ac-i2i-engineering/starred{/owner}{/repo}",
#             "subscriptions_url": "https://api.github.com/users/ac-i2i-engineering/subscriptions",
#             "organizations_url": "https://api.github.com/users/ac-i2i-engineering/orgs",
#             "repos_url": "https://api.github.com/users/ac-i2i-engineering/repos",
#             "events_url": "https://api.github.com/users/ac-i2i-engineering/events{/privacy}",
#             "received_events_url": "https://api.github.com/users/ac-i2i-engineering/received_events",
#             "type": "Organization",
#             "user_view_type": "public",
#             "site_admin": false
#           },
#           "repo": {
#             "id": 892743361,
#             "node_id": "R_kgDONTYuwQ",
#             "name": "resumax",
#             "full_name": "ac-i2i-engineering/resumax",
#             "private": false,
#             "owner": {
#               "login": "ac-i2i-engineering",
#               "id": 171437024,
#               "node_id": "O_kgDOCjfr4A",
#               "avatar_url": "https://avatars.githubusercontent.com/u/171437024?v=4",
#               "gravatar_id": "",
#               "url": "https://api.github.com/users/ac-i2i-engineering",
#               "html_url": "https://github.com/ac-i2i-engineering",
#               "followers_url": "https://api.github.com/users/ac-i2i-engineering/followers",
#               "following_url": "https://api.github.com/users/ac-i2i-engineering/following{/other_user}",
#               "gists_url": "https://api.github.com/users/ac-i2i-engineering/gists{/gist_id}",
#               "starred_url": "https://api.github.com/users/ac-i2i-engineering/starred{/owner}{/repo}",
#               "subscriptions_url": "https://api.github.com/users/ac-i2i-engineering/subscriptions",
#               "organizations_url": "https://api.github.com/users/ac-i2i-engineering/orgs",
#               "repos_url": "https://api.github.com/users/ac-i2i-engineering/repos",
#               "events_url": "https://api.github.com/users/ac-i2i-engineering/events{/privacy}",
#               "received_events_url": "https://api.github.com/users/ac-i2i-engineering/received_events",
#               "type": "Organization",
#               "user_view_type": "public",
#               "site_admin": false
#             },
#             "html_url": "https://github.com/ac-i2i-engineering/resumax",
#             "description": null,
#             "fork": false,
#             "url": "https://api.github.com/repos/ac-i2i-engineering/resumax",
#             "forks_url": "https://api.github.com/repos/ac-i2i-engineering/resumax/forks",
#             "keys_url": "https://api.github.com/repos/ac-i2i-engineering/resumax/keys{/key_id}",
#             "collaborators_url": "https://api.github.com/repos/ac-i2i-engineering/resumax/collaborators{/collaborator}",
#             "teams_url": "https://api.github.com/repos/ac-i2i-engineering/resumax/teams",
#             "hooks_url": "https://api.github.com/repos/ac-i2i-engineering/resumax/hooks",
#             "issue_events_url": "https://api.github.com/repos/ac-i2i-engineering/resumax/issues/events{/number}",
#             "events_url": "https://api.github.com/repos/ac-i2i-engineering/resumax/events",
#             "assignees_url": "https://api.github.com/repos/ac-i2i-engineering/resumax/assignees{/user}",
#             "branches_url": "https://api.github.com/repos/ac-i2i-engineering/resumax/branches{/branch}",
#             "tags_url": "https://api.github.com/repos/ac-i2i-engineering/resumax/tags",
#             "blobs_url": "https://api.github.com/repos/ac-i2i-engineering/resumax/git/blobs{/sha}",
#             "git_tags_url": "https://api.github.com/repos/ac-i2i-engineering/resumax/git/tags{/sha}",
#             "git_refs_url": "https://api.github.com/repos/ac-i2i-engineering/resumax/git/refs{/sha}",
#             "trees_url": "https://api.github.com/repos/ac-i2i-engineering/resumax/git/trees{/sha}",
#             "statuses_url": "https://api.github.com/repos/ac-i2i-engineering/resumax/statuses/{sha}",
#             "languages_url": "https://api.github.com/repos/ac-i2i-engineering/resumax/languages",
#             "stargazers_url": "https://api.github.com/repos/ac-i2i-engineering/resumax/stargazers",
#             "contributors_url": "https://api.github.com/repos/ac-i2i-engineering/resumax/contributors",
#             "subscribers_url": "https://api.github.com/repos/ac-i2i-engineering/resumax/subscribers",
#             "subscription_url": "https://api.github.com/repos/ac-i2i-engineering/resumax/subscription",
#             "commits_url": "https://api.github.com/repos/ac-i2i-engineering/resumax/commits{/sha}",
#             "git_commits_url": "https://api.github.com/repos/ac-i2i-engineering/resumax/git/commits{/sha}",
#             "comments_url": "https://api.github.com/repos/ac-i2i-engineering/resumax/comments{/number}",
#             "issue_comment_url": "https://api.github.com/repos/ac-i2i-engineering/resumax/issues/comments{/number}",
#             "contents_url": "https://api.github.com/repos/ac-i2i-engineering/resumax/contents/{+path}",
#             "compare_url": "https://api.github.com/repos/ac-i2i-engineering/resumax/compare/{base}...{head}",
#             "merges_url": "https://api.github.com/repos/ac-i2i-engineering/resumax/merges",
#             "archive_url": "https://api.github.com/repos/ac-i2i-engineering/resumax/{archive_format}{/ref}",
#             "downloads_url": "https://api.github.com/repos/ac-i2i-engineering/resumax/downloads",
#             "issues_url": "https://api.github.com/repos/ac-i2i-engineering/resumax/issues{/number}",
#             "pulls_url": "https://api.github.com/repos/ac-i2i-engineering/resumax/pulls{/number}",
#             "milestones_url": "https://api.github.com/repos/ac-i2i-engineering/resumax/milestones{/number}",
#             "notifications_url": "https://api.github.com/repos/ac-i2i-engineering/resumax/notifications{?since,all,participating}",
#             "labels_url": "https://api.github.com/repos/ac-i2i-engineering/resumax/labels{/name}",
#             "releases_url": "https://api.github.com/repos/ac-i2i-engineering/resumax/releases{/id}",
#             "deployments_url": "https://api.github.com/repos/ac-i2i-engineering/resumax/deployments",
#             "created_at": "2024-11-22T17:33:54Z",
#             "updated_at": "2025-03-15T21:49:54Z",
#             "pushed_at": "2025-03-18T03:52:43Z",
#             "git_url": "git://github.com/ac-i2i-engineering/resumax.git",
#             "ssh_url": "git@github.com:ac-i2i-engineering/resumax.git",
#             "clone_url": "https://github.com/ac-i2i-engineering/resumax.git",
#             "svn_url": "https://github.com/ac-i2i-engineering/resumax",
#             "homepage": null,
#             "size": 779,
#             "stargazers_count": 0,
#             "watchers_count": 0,
#             "language": "Python",
#             "has_issues": true,
#             "has_projects": true,
#             "has_downloads": true,
#             "has_wiki": true,
#             "has_pages": false,
#             "has_discussions": false,
#             "forks_count": 0,
#             "mirror_url": null,
#             "archived": false,
#             "disabled": false,
#             "open_issues_count": 1,
#             "license": {
#               "key": "mit",
#               "name": "MIT License",
#               "spdx_id": "MIT",
#               "url": "https://api.github.com/licenses/mit",
#               "node_id": "MDc6TGljZW5zZTEz"
#             },
#             "allow_forking": true,
#             "is_template": false,
#             "web_commit_signoff_required": false,
#             "topics": [],
#             "visibility": "public",
#             "forks": 0,
#             "open_issues": 1,
#             "watchers": 0,
#             "default_branch": "main"
#           }
#         },
#         "_links": {
#           "self": {
#             "href": "https://api.github.com/repos/ac-i2i-engineering/resumax/pulls/16"
#           },
#           "html": {
#             "href": "https://github.com/ac-i2i-engineering/resumax/pull/16"
#           },
#           "issue": {
#             "href": "https://api.github.com/repos/ac-i2i-engineering/resumax/issues/16"
#           },
#           "comments": {
#             "href": "https://api.github.com/repos/ac-i2i-engineering/resumax/issues/16/comments"
#           },
#           "review_comments": {
#             "href": "https://api.github.com/repos/ac-i2i-engineering/resumax/pulls/16/comments"
#           },
#           "review_comment": {
#             "href": "https://api.github.com/repos/ac-i2i-engineering/resumax/pulls/comments{/number}"
#           },
#           "commits": {
#             "href": "https://api.github.com/repos/ac-i2i-engineering/resumax/pulls/16/commits"
#           },
#           "statuses": {
#             "href": "https://api.github.com/repos/ac-i2i-engineering/resumax/statuses/a066011282ada6b2fc4463db2d66b9f09cbc944c"
#           }
#         },
#         "author_association": "COLLABORATOR",
#         "auto_merge": null,
#         "active_lock_reason": null
#       }
#     },
#     "public": true,
#     "created_at": "2025-03-18T03:53:03Z",
#     "org": {
#       "id": 171437024,
#       "login": "ac-i2i-engineering",
#       "gravatar_id": "",
#       "url": "https://api.github.com/orgs/ac-i2i-engineering",
#       "avatar_url": "https://avatars.githubusercontent.com/u/171437024?"
#     }
#   },
#   {
#     "id": "47666338053",
#     "type": "PublicEvent",
#     "actor": {
#       "id": 157810432,
#       "login": "momo-41",
#       "display_login": "momo-41",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/momo-41",
#       "avatar_url": "https://avatars.githubusercontent.com/u/157810432?"
#     },
#     "repo": {
#       "id": 935264940,
#       "name": "momo-41/thank-you-yuse",
#       "url": "https://api.github.com/repos/momo-41/thank-you-yuse"
#     },
#     "payload": {},
#     "public": true,
#     "created_at": "2025-03-18T03:53:03Z"
#   }
# ]
# '[{"id":"47666338179","type":"CreateEvent","actor":{"id":202667464,"login":"DianaPutri09","display_login":"DianaPutri09","gravatar_id":"","url":"https://api.github.com/users/DianaPutri09","avatar_url":"https://avatars.githubusercontent.com/u/202667464?"},"repo":{"id":950369337,"name":"DianaPutri09/Simple-Finding-Path---BFS","url":"https://api.github.com/repos/DianaPutri09/Simple-Finding-Path---BFS"},"payload":{"ref":"main","ref_type":"branch","master_branch":"main","description":null,"pusher_type":"user"},"public":true,"created_at":"2025-03-18T03:53:03Z"},{"id":"47666338106","type":"PushEvent","actor":{"id":41898282,"login":"github-actions[bot]","display_login":"github-actions","gravatar_id":"","url":"https://api.github.com/users/github-actions[bot]","avatar_url":"https://avatars.githubusercontent.com/u/41898282?"},"repo":{"id":813600738,"name":"SofyanJames/Lava-testnet","url":"https://api.github.com/repos/SofyanJames/Lava-testnet"},"payload":{"repository_id":813600738,"push_id":23228177674,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"b5de520623a5f316daff1c4b17652db6082d1b20","before":"9018e6338fad5142c9d6e4c104e3b6979ecbb616","commits":[{"sha":"b5de520623a5f316daff1c4b17652db6082d1b20","author":{"email":"sofyanjames71@gmail.com","name":"SofyanJames"},"message":"🔧 Refactor NEAR network","distinct":true,"url":"https://api.github.com/repos/SofyanJames/Lava-testnet/commits/b5de520623a5f316daff1c4b17652db6082d1b20"}]},"public":true,"created_at":"2025-03-18T03:53:03Z"},{"id":"47666338126","type":"PushEvent","actor":{"id":41898282,"login":"github-actions[bot]","display_login":"github-actions","gravatar_id":"","url":"https://api.github.com/users/github-actions[bot]","avatar_url":"https://avatars.githubusercontent.com/u/41898282?"},"repo":{"id":840148192,"name":"nectariferous/TestFlight","url":"https://api.github.com/repos/nectariferous/TestFlight"},"payload":{"repository_id":840148192,"push_id":23228177701,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"f8c8eb3b525c76993df2fff944bffb6298e5e6b7","before":"3b70a232cebda487c0f87ec0b42a8210be96056b","commits":[{"sha":"f8c8eb3b525c76993df2fff944bffb6298e5e6b7","author":{"email":"ibbles@hotmail.com","name":"Martin Nilsson"},"message":"Daily update at 2025-03-18 03:53:01","distinct":true,"url":"https://api.github.com/repos/nectariferous/TestFlight/commits/f8c8eb3b525c76993df2fff944bffb6298e5e6b7"}]},"public":true,"created_at":"2025-03-18T03:53:03Z"},{"id":"47666338107","type":"PushEvent","actor":{"id":41898282,"login":"github-actions[bot]","display_login":"github-actions","gravatar_id":"","url":"https://api.github.com/users/github-actions[bot]","avatar_url":"https://avatars.githubusercontent.com/u/41898282?"},"repo":{"id":812864746,"name":"taktikorg/exercitationem-modi-dicta","url":"https://api.github.com/repos/taktikorg/exercitationem-modi-dicta"},"payload":{"repository_id":812864746,"push_id":23228177659,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"40e8fffb4b6b0b8a745de0244b84fc80ace93c07","before":"dc8092a6157537ed966376ad1f7df6c5df318413","commits":[{"sha":"40e8fffb4b6b0b8a745de0244b84fc80ace93c07","author":{"email":"12395584+taktikangt6@users.noreply.github.com","name":"taktikangt6"},"message":"New updated version 8.27.247","distinct":true,"url":"https://api.github.com/repos/taktikorg/exercitationem-modi-dicta/commits/40e8fffb4b6b0b8a745de0244b84fc80ace93c07"}]},"public":true,"created_at":"2025-03-18T03:53:03Z","org":{"id":167952281,"login":"taktikorg","gravatar_id":"","url":"https://api.github.com/orgs/taktikorg","avatar_url":"https://avatars.githubusercontent.com/u/167952281?"}},{"id":"47666338130","type":"IssueCommentEvent","actor":{"id":23240686,"login":"VaterOtter","display_login":"VaterOtter","gravatar_id":"","url":"https://api.github.com/users/VaterOtter","avatar_url":"https://avatars.githubusercontent.com/u/23240686?"},"repo":{"id":932465330,"name":"koii-network/prometheus-beta","url":"https://api.github.com/repos/koii-network/prometheus ...
